# %%
# 文字列に関して
# ※シングルクォート('')、ダブルクォート("")のどちらでも可

# 1.変数に文字列を代入する
# word = 'Hello!!'
# word    # 出力


# 2.変数の型の確認する
# type(word)
# type(123)    # 出力


# 3.組み込み関数(str)で型変換する
# 文字列に変換
# word = str(123)
# word    # 出力

# 文字列を数字に変換
# 整数の場合
# num = int('123')
# num    # 出力

# 実数(浮動小数点)の場合
# f = float('123.4')
# f    # 出力


# 4.文字列の長さを取得する
# ループの時によく使うかも
# len(word)    # 出力


# 5.文字列の特定の文字を取得する(要素数のことをインデックスと呼ぶ)
# ※文字列より大きい要素数を指定してしまうとエラーとなる(IndexError)
# ※要素数を指定して中身のデータを変更することは出来ない(TypeError)
# ※要素数はマイナス値でも指定出来るが、要素数の最大値から順に数えること
# 'Hello'['要素数を入力']
# 'Hello'[2]    # 出力

# 変数に文字列を代入した場合でも要素数で指定した文字を取得できる
# word = 'Hello'
# word[1]    # 出力


# 6.文字列の一部を取得する(スライス)
# digits = '0123456789'
# digits[1:4]     # 要素数1から4の範囲を取得(digits[:4]でも同じ結果になる)
# digits[:3]      # 最初の0を省略してもOK(範囲は0～3まで)
# digits[3:]      # 要素数3から要素数の最大値まで取得
# digits[-4:-1]   # マイナス値でも使用可能

# とびとびで文字列を取得する
# digits[3:9:2]   # 要素数3から9の範囲から2文字おきに飛んで取得する
# digits[8:4:-1]  # マイナス値も使用可能


# 7.空文字列
# blank = ''    # 何もない文字列を空列(くうれつ)or空文字列と言います
# 文字列の中にある部分文字列を取り除く
# price = '2,980円'
# price.replace(',','')   # replace('A','B')は指定した文字Aを文字Bに置き換えることができる
# replaceされた変数の値は変化しないので注意!!

# 豆知識
# digits = '0123456789'
# print('空文字列1 = ',digits[4:2])         # 出力されていないように見えるが空文字列が結果として入ってる
# print('空文字列1 = ',digits[-1:-4])       # 出力されていないように見えるが空文字列が結果として入ってる
# print('空文字列1 = ',digits[3:3])         # 出力されていないように見えるが空文字列が結果として入ってる
# print('空文字列ではない ',digits[3:-1])   # 出力される


# 文字列の検索
# 文字列B in 文字列A      # 文字列Aに文字列Bがあるかどうかを調べる
# 'lo' in  'Hello'    # 結果はフラグを返す(True,False)

# 文字列を値として変数に持たせる場合
# word = 'Hello'
# str = 'lo'
# str in word    # 出力

# 文字列B not in 文字列A      # 文字列Aに文字列Bがないかどうかを調べる
# word = 'Hello'
# str = 'a'
# str not in word    # 出力


# エスケープシーケンス(特殊な文字列)
# non_escaped = 'This is 'MINE''
# non_escaped    # 出力
# 上記のコードではSytaxErrorが出るのでエラーを避けるために一手間加える
# ↓
# non_escaped = 'This is \'MINE\''
# non_escaped    # 出力

# クォート内に同じクォートがあるとSytaxErrorが出ると覚えればよさそう

# ダブルクォートとシングルクォートを使用した場合
# quated = "This is 'MINE'"   # ダブルクォートの中にシングルクォート
# quated    # 出力
# quated = 'This is "MINE"'   # シングルクォートの中にダブルクォート
# quated    # 出力


# 文字列の連結
# 変数 + 変数
# word = 'Hello'
# str = 'World'
# text = word + str
# text    # 出力

# 繰り返し回数でも可能
# 変数 * 回数
# word = 'Hello'
# word * 3    # 出力


# 文字列の検索(部分文字列が文字列のどこに存在するのかを調べる)
# 文字列.index(部分文字列)
# word = 'Hello'
# word.index('lo')

# 文字列.find(部分文字列)
# word = 'Hello'
# word.find('e')    # 出力
# word.find('a')    # エラーは出ずに-1が返される


# 文字列の数え上げ(部分文字列が文字列にいくつ存在するか調べる)
# 文字列.count(部分文字列)
# word = 'Hello'
# word.count('l')    # 出力
# 'aaaaaa'.count('aa')    # あまり望ましくないが出力は可能


# 大文字、小文字
# 文字列の中を大文字、小文字に変換する(元の文字列は変化しない)

# 文字列の全ての文字を大文字にする
# lower_word = 'STR'
# lower_word.upper()

# 文字列の全ての文字を小文字にする
# upper_word = 'STR'
# upper_word.lower()

# 先頭の文字を大文字にする
# lower_word = 'helloworld'
# lower_word.capitalize()


# 空白文字の削除
# 空白文字には{' '(半角),\n,\t,’’(全角)}などがある
# '　abc\n'.strip()       # 全角スペース、改行
# '　a b c \n'.strip()    # 全角スペース、半角スペース、改行
# 左側空白だけ削除することも右側空白だけ削除することも可能
# 左側空白の場合
# '　abc\n'.lstrip()    # 全角スペースを削除
# 右側空白の場合
# '  abc\n'.rstrip()    # 改行削除


# 文字の比較演算
# 条件分岐でよく使う
# 文字列の条件分岐は完全一致じゃないとFalseになるよ
# print('abc' == 'abc')   # True
# print('abc' == 'ab')    # False

# print('abc' != 'abc')   # False
# print('abc' != 'ab')    # True


# 大小の比較は文字列の最初から順に比較する(辞書型)
# 長さが異なる場合は個数が多いほうが大きい
# print('abc' <= 'abc')   # True
# print('abc' < 'abc')    # False
# print('abc' < 'abd')    # True
# print('ab' < 'abc')     # True
