# %% [markdown]
# <a href="https://colab.research.google.com/github/U-myami/Google_Colab_p/blob/main/%E7%B7%B4%E7%BF%92%E5%95%8F%E9%A1%8C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 構造体
from dataclasses import dataclass

# 個人情報
@dataclass
class Person:
  address: str
  name: str

# 配列
japanese = [["大阪","田中"],["北海道","山内"],
            ["奈良","中野"],["広島","山田"],
            ["大分","大谷"],["島根","寺岡"],
            ["鹿児島","田村"],["静岡","野口"],
            ["福島","高山"],["神奈川","中村"]
            ]

#★やってほしいこと : adressには"島"、nameには"田"がある部分を★
#★別の配列に格納して出力してください★

#新規配列作成・条件に合うものを選択したいので変数を[selected]とする
selected = []


#リスト操作・for使用・新規配列内に登録したいので変数を[entry]とする
for entry in japanese:
  address = entry [0]  #都道府県
  name= entry [1]     #名前

#条件分岐使用・条件に当てはまったもののみ抽出
  if "島" in address and "田" in name:
    selected.append(entry)

print(selected)
# Out:
# [['広島', '山田'], ['鹿児島', '田村']]

# %% [markdown]
# 2026/02/27→中村のリポジトリが文字化けを起こし現在解決方法を模索中ですが、まだ対応不可のため、申し訳ございませんが谷野さんのリポジトリに直接格納させていただきます。ご確認お願いいたします。

# %% [markdown]
# 追加したいよ→append関数使用
# ・出力結果が[]になった理由→for分とif分が別のブロックになっていた(インデントミス)
