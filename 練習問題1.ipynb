# %%
# 構造体
from dataclass import dataclass

# 個人情報
@dataclass
class Person:
  address: int
  name: str

# 配列
japanese = [["大阪","田中"],["北海道","山内"],
            ["奈良","中野"],["広島","山田"],
            ["大分","大谷"],["島根","寺岡"],
            ["鹿児島","田村"],["静岡","野口"],
            ["福島","高山"],["神奈川","中村"]
            ]


# やってほしいこと : adressには"島"、nameには"田"がある部分を
# 別の配列に格納して出力してください
